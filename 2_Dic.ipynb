# %% [markdown]
# <a href="https://colab.research.google.com/github/FernandoMartinezHernandez/daa_2021_1/blob/master/2_Dic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def fnRecInfinita():
  print("Hola")
  fnRecInfinita()

fnRecInfinita()
# Out:
# Hola
# Hola
# Hola
# Hola
# Hola
# Hola
# Hola
# Hola
# Hola
# Hola
# Hola
# Hola
# Hola
# Hola
# Hola
# Hola
# Hola
# Hola
# Hola
# Hola
# Hola
# Hola
# Hola
# Hola
# Hola
# Hola
# Hola
# Hola
# Hola
# Hola
# Hola
# Hola
# Hola
# Hola
# Hola
# Hola
# Hola
# Hola
# Hola
# Hola
# Hola
# Hola
# Hola
# Hola
# Hola
# Hola
# Hola
# Hola
# Hola
# Hola
# Hola
# Hola
# Hola
# Hola
# Hola
# Hola
# Hola
# Hola
# Hola
# Hola
# Hola
# Hola
# Hola
# Hola
# Hola
# Hola
# Hola
# Hola
# Hola
# Hola
# Hola
# Hola
# Hola
# Hola
# Hola
# Hola
# Hola
# Hola
# Hola
# Hola
# Hola
# Hola
# Hola
# Hola
# Hola
# Hola
# Hola
# Hola
# Hola
# Hola
# Hola
# Hola
# Hola
# Hola
# Hola
# Hola
# Hola
# Hola
# Hola
# Hola
# Hola
# Hola
# Hola
# Hola
# Hola
# Hola
# Hola
# Hola
# Hola
# Hola
# Hola
# Hola
# Hola
# Hola
# Hola
# Hola
# Hola
# Hola
# Hola
# Hola
# Hola
# Hola
# Hola
# Hola
# Hola
# Hola
# Hola
# Hola
# Hola
# Hola
# Hola
# Hola
# Hola
# Hola
# Hola
# Hola
# Hola
# Hola
# Hola
# Hola
# Hola
# Hola
# ...

# %%
def fnRec(x):

    if x==0:
      print("Stop")
    else:
      print(x)
      fnRec(x-1)

def main():
  print("Inicio del programa")
  fnRec(5)
  print("Fin del programa")

main()
# Out:
# Inicio del programa
# 5
# 4
# 3
# 2
# 1
# Stop
# Fin del programa

# %%
def printRev(x):
  if x>0:
    
    printRev(x-1)
    print(x)

printRev(3)
# Out:
# 1
# 2
# 3

# %%
def fibonaci(n):
  if n== 1 or n ==0:
    return n
  else:
    return (fibonaci(n-1) + fibonaci (n-2))

print(fibonaci(8))
# Out:
# 21
